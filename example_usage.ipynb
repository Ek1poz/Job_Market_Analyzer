# %% [markdown]
# # Job Market Analysis Report
# Analysis of Data Science salaries based on the provided dataset.

# %%
import pandas as pd
from job_market import JobAnalyzer, JobVisualizer

filename = 'ds_salaries.csv'
analyzer = JobAnalyzer(filename)

# %% [markdown]
# ## 1. Financial Statistics (USD)
# Overview of the salary ranges in the market.

# %%
stats = analyzer.get_salary_stats_table()
stats
# Out:
#     min     max        avg    median
# 0  2859  600000  112297.87  101570.0

# %% [markdown]
# ## 2. Top Job Titles
# The most popular professions in the dataset.

# %%
top_jobs = analyzer.get_top_professions_table(5)
top_jobs
# Out:
#                    Job Title  Vacancies Count
# 0             Data Scientist              143
# 1              Data Engineer              132
# 2               Data Analyst               97
# 3  Machine Learning Engineer               41
# 4         Research Scientist               16

# %% [markdown]
# ## 3. The richest job

# %%
richest = analyzer.get_richest_job()

richest
# Out:
#                    Job Title  Salary (USD) Experience
# 252  Principal Data Engineer        600000         EX

# %% [markdown]
# ## 4. Stats table by experience

# %%
experience_stat_table = analyzer.get_experience_stats_table()

experience_stat_table
# Out:
#        Experience Level     Avg Salary
# 0  Entry-level (Junior)   61643.318182
# 1             Mid-level   87996.056338
# 2                Senior  138617.292857
# 3             Executive  199392.038462

# %% [markdown]
# ## 5. Salary growth for particular job based on experience

# %%
job_name = "Data Scientist"

analyzer.get_salary_growth_for_job(job_name)
# Out:
#        Experience Level     Avg Salary
# 0  Entry-level (Junior)   55330.909091
# 1             Mid-level   82039.133333
# 2                Senior  152971.016393

# %% [markdown]
# ## 6. Visualizations
# Distribution of salaries and job popularity.

# %%
viz = JobVisualizer(analyzer.get_data())

viz.plot_salary_distribution()
viz.plot_top_jobs(10)
viz.plot_salary_by_job(10)
viz.plot_experience_salaries()
# Out:
# d:\Labs\SPL\РГР\job_market\visualizer.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top.values, y=top.index, palette='viridis')
# d:\Labs\SPL\РГР\job_market\visualizer.py:42: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_filtered, x='salary_in_usd', y='job_title', palette='coolwarm')
# d:\Labs\SPL\РГР\job_market\visualizer.py:59: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data.index, y=data.values, palette='magma')
